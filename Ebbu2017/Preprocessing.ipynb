# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("./balanced_urls_clean.csv")

# %%
df.head()
df.drop(columns='Unnamed: 0',axis=1,inplace=True)

# %%
def initial_read(df):
    print('SHAPE')
    print(df.shape)
    print('=====')
    print('DTYPES')
    print(df.dtypes)
    print('=====')
    print('NULL VALUES')
    print(df.isnull().sum())
    print('=====')
initial_read(df)
# Out:
# SHAPE
# (73575, 2)
# =====
# DTYPES
# url      object
# label     int64
# dtype: object
# =====
# NULL VALUES
# url      0
# label    0
# dtype: int64
# =====

# %%
print(df.columns)
# Out:
# Index(['url', 'label'], dtype='object')

# %%
plt.figure(figsize = (5, 7))        
bar = sns.countplot(x=df["label"], 
              data=df, 
              palette="Reds")
for p in bar.patches:
    bar.annotate(format(p.get_height(), ','), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')
plt.title('Frequency of Legitimate and Phishing URLs', fontsize = 16, pad = 12)
plt.xlabel('Legitimate (0), Phishing (1)', fontsize = 14)
plt.ylabel("Frequency",fontsize = 14)
plt.show();

# %% [markdown]
# # Feature Engineering

# %%
import urllib
from urllib.parse import urlparse
import os.path

# %%
# !pip install tld
# Out:
# Requirement already satisfied: tld in d:\anaconda\lib\site-packages (0.13)

# %%
df['url_length'] = df['url'].apply(lambda i: len(str(i)))
df['hostname_length'] = df['url'].apply(lambda i: len(urlparse(i).netloc))
df['path_length'] = df['url'].apply(lambda i: len(urlparse(i).path))
def fd_length(url):
    urlpath= urlparse(url).path
    try:
        return len(urlpath.split('/')[1])
    except:
        return 0

df['fd_length'] = df['url'].apply(lambda i: fd_length(i))

# %%
characters_to_count = ['-', '@', '?', '%', '.', '=']
df['spcl_char'] = df['url'].apply(lambda i: sum(i.count(char) for char in characters_to_count))

df['count-http'] = df['url'].apply(lambda i : i.count('http'))
df['count-https'] = df['url'].apply(lambda i : i.count('https'))
df['count-www'] = df['url'].apply(lambda i: i.count('www'))

def digit_count(url):
    digits = 0
    for i in url:
        if i.isnumeric():
            digits = digits + 1
    return digits
df['count-digits']= df['url'].apply(lambda i: digit_count(i))

def letter_count(url):
    letters = 0
    for i in url:
        if i.isalpha():
            letters = letters + 1
    return letters
df['count-letters']= df['url'].apply(lambda i: letter_count(i))

def no_of_dir(url):
    urldir = urlparse(url).path
    return urldir.count('/')
df['count_dir'] = df['url'].apply(lambda i: no_of_dir(i))

df['path_entropy'] = df['url'].apply(lambda x: -sum([(x.count(c) / len(x)) * (x.count(c) / len(x)) for c in set(x)]))

# %%
def count_subdomains(url):
    parsed_url = urlparse(url)
    netloc = parsed_url.netloc
    subdomains = netloc.split('.')
    subdomains = [subdomain for subdomain in subdomains if subdomain != '']
    return len(subdomains)

# Apply the function to calculate subdomain counts and append to 'subdomain' column
df['subdomain'] = df['url'].apply(count_subdomains)

# %%
df.head()
# Out:
#                                                  url  label  url_length  \
# 0  http://www.conceptdraw.com/How-To-Guide/Local-...      0          58
# 1   https://www.edrawsoft.com/Local-Area-Network.php      0          48
# 2  http://www.webopedia.com/TERM/L/local_area_net...      0          59
# 3      https://www.acsac.org/secshelf/book001/16.pdf      0          45
# 4        http://www.diffen.com/difference/LAN_vs_WAN      0          43
#
#    hostname_length  path_length  fd_length  spcl_char  count-http  \
# 0               19           32         12          6           1
# 1               17           23         22          5           1
# 2               17           35          4          3           1
# 3               13           24          8          3           1
# 4               14           22         10          2           1
#
#    count-https  count-www  count-digits  count-letters  count_dir  \
# 0            0          1             0             47          2
# 1            1          1             0             39          1
# 2            0          1             0             47          3
# 3            1          1             5             31          3
# 4            0          1             0             34          2
#
#    path_entropy  subdomain
# 0     -0.058264          3
# 1     -0.059028          3
# 2     -0.050847          3
# 3     -0.057778          3
# 4     -0.055706          3

# %% [markdown]
#  Understanding Distribution of features and differences betweeen benign and phishing URLs

# %%
num_cols = df.select_dtypes(exclude='object')

# %%
for col in num_cols:
    column_name = col.title().replace('_', ' ')
    title = 'Distribution of ' + column_name
    sns.boxplot(x=df[col],
                y=df['label'],
                data=df,
                orient='h',
                showmeans=True,
                meanprops={"marker":"o",
                           "markerfacecolor":"white", 
                           "markeredgecolor":"black",
                           "markersize":"7"})
    plt.xlabel(column_name, fontsize = 12)
    plt.ylabel('Phishing URL', fontsize = 12)
    plt.title(title, fontsize = 14, pad = 10)
    plt.show()

# %%
plt.figure(figsize=(9,6))
sns.histplot(data=df, x=df["url_length"], hue = 'label', bins=100)
plt.title('Distribution of URL Length (with Outliers)', fontsize = 18, pad = 12)
plt.xlabel("URL Length", fontsize = 15)
plt.ylabel("Count",fontsize = 15)
plt.show()

# %%
Q1 = df['url_length'].quantile(0.25)
Q3 = df['url_length'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

filtered_url_length = df[(df['url_length']> lower_bound)]
filtered_url_length = df[(df['url_length']< upper_bound)]

# %%
plt.figure(figsize=(9,6))
sns.histplot(data=filtered_url_length, x="url_length", hue = 'label', bins = 100)
plt.title('Distribution of URL Length (without Outliers)', fontsize = 18, pad = 12)
plt.xlabel("URL Length", fontsize = 15)
plt.ylabel("Count",fontsize = 15);
plt.show()

# %%
plt.figure(figsize=(6,20))
sns.heatmap(df.corr()[['label']].sort_values('label', ascending=False), annot=True);

# %%
df.to_csv('./url_updated.csv', index=False)
